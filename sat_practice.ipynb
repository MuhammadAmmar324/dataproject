# %%
import pandas as pd
import numpy as np

df=pd.DataFrame({
  "name":["alice","bob","ammar",np.NaN],
    "gpa":[3.1,4,3.5,np.NaN],
    "semester":[3,3,6,np.NaN],
    "id":[230,654,345,np.NaN]

})
print(df)
# Out:
#     name  gpa  semester     id
# 0  alice  3.1       3.0  230.0
# 1    bob  4.0       3.0  654.0
# 2  ammar  3.5       6.0  345.0
# 3    NaN  NaN       NaN    NaN

# %%
df.loc[3]
# Out:
# name        NaN
# gpa         NaN
# semester    NaN
# id          NaN
# Name: 3, dtype: object

# %%
df['gpa']
# Out:
# 0    3.1
# 1    4.0
# 2    3.5
# 3    NaN
# Name: gpa, dtype: float64

# %%
df.dropna(how='all')
# Out:
#     name  gpa  semester     id
# 0  alice  3.1       3.0  230.0
# 1    bob  4.0       3.0  654.0
# 2  ammar  3.5       6.0  345.0

# %%
data=pd.read_csv('/content/canada_per_capita_income.csv')
data
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 880.0 bytes

# %% [markdown]
# data.describe()

# %%
data.isnull()
# Out:
#      year  per capita income (US$)
# 0   False                    False
# 1   False                    False
# 2   False                    False
# 3   False                    False
# 4   False                    False
# 5   False                    False
# 6   False                    False
# 7   False                    False
# 8   False                    False
# 9   False                    False
# 10  False                    False
# 11  False                    False
# 12  False                    False
# 13  False                    False
# 14  False                    False
# 15  False                    False
# 16  False                    False
# 17  False                    False
# 18  False                    False
# 19  False                    False
# 20  False                    False
# 21  False                    False
# 22  False                    False
# 23  False                    False
# 24  False                    False
# 25  False                    False
# ...
